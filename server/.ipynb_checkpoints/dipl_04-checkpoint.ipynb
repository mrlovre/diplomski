# %% [markdown]
# # Diplomski rad 4
#
# 26\. travnja 2017.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import graphviz as gv

import networkx as nx
import pydot
import os
from utility.log_progress import log_progress
from importlib import reload
import utility.functions
reload(utility.functions)
from utility.functions import *
from collections import Counter

matplotlib.rcParams['figure.figsize'] = (16, 9)

# %%
# cijene
sp500 = np.genfromtxt('data/stock_prices_sp500.csv', delimiter=',')
sp500_5 = sp500[::5, ...]
sp500_22 = sp500[::22, ...]

days, N = sp500.shape
P = N * (N - 1) // 2

# log-cijene
sp500_log = np.log(sp500)
sp500_5_log = np.log(sp500_5)
sp500_22_log = np.log(sp500_22)

# razlike log cijena po parovima
sp500_log_diffs = calculate_pairwise_diffs(sp500_log)
sp500_5_log_diffs = calculate_pairwise_diffs(sp500_5_log)
sp500_22_log_diffs = calculate_pairwise_diffs(sp500_22_log)

# %%
for d in [2.0, 2.5, 3.0, 3.6, 3.75, 3.9]:
    p = None
    T = 200

    method = 'thresh-devs'

    sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_log_diffs, T)
    ts, profits, pairs, weights = statistical_arbitrage(sp500_log_diffs, sp500_log_diff_means, sp500_log_diff_vars, p=p, d=d,
                                                        method=method, return_pairs=True, return_weights=True)

    ppairs = partition_as(ts, pairs, weights)
    profit = []
    shares = []
    ts_plot = []
    exp_tops = []
    exp_bottoms = []
    e = 0.0
    for t, ppair, weight in log_progress(list(ppairs)):
        preferences = calculate_preference_flow(ppair, weights=weight)
        m = max(np.abs(list(preferences.values())))
        tops = np.array([k for k, v in preferences.items() if v >= m - e])
        bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
        p = []
        if len(tops) != 0:
            ttops = np.array([t] * len(tops))
            p.extend(trade_singles(sp500_log, ttops, tops, inv=False))
            shares.extend(tops)
            ts_plot.extend(ttops)
        if len(bottoms) != 0:
            tbottoms = np.array([t] * len(bottoms))
            p.extend(trade_singles(sp500_log, tbottoms, bottoms, inv=True))
            shares.extend(bottoms)
            ts_plot.extend(tbottoms)
        exp_tops += [set(tops)]
        exp_bottoms += [set(bottoms)]
        profit.extend([p_ / len(p) for p_ in p])

    shares = np.array(shares)
    ts_plot = np.array(ts_plot)
    profit = np.array(profit)
    
    turnover_top = turnover_ratio(exp_tops)
    turnover_bottom = turnover_ratio(exp_bottoms)

    ts1, profit1 = join_ts_profit(ts_plot, profit)

    plt.figure()
    plt.title('d = {}'.format(d))
    plt.plot(ts1, np.cumsum(profit1))
    plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
    plt.legend(['profit', 'transaction cost included'], loc='best')
    plt.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

    avg = np.mean(profit) * 252
    std = np.std(profit) * np.sqrt(252)
    sharpe = avg / std

    total_positive = np.sum(profit[np.greater(profit, 0.0)])
    total_negative = np.sum(profit[np.less_equal(profit, 0.0)])
    
    print('d = {}'.format(d))
    print('  Avg (year): {:.5f}'.format(avg))
    print('  Stddev (year): {:.5f}'.format(std))
    print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
    print('  Profit:')
    print('    positive only: {:.5f}'.format(total_positive))
    print('    negative only: {:.5f}'.format(total_negative))
    print('    total: {:.5f}'.format(total_positive + total_negative))
    print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
    print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
    print('  Average turnovers (range [0, 2]):')
    print('    top: {:.5f}'.format(np.mean(turnover_top)))
    print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
    print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
    print('  Total turnovers:')
    print('    top: {:.5f}'.format(np.sum(turnover_top)))
    print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
    print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
    print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
        np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# d = 2.0
#   Avg (year): 1.00576
#   Stddev (year): 0.78247
#   Sharpe ratio (year): 1.28536
#   Profit:
#     positive only: 82.06337
#     negative only: -57.87335
#     total: 24.19003
#     positive to negative ratio: 1.41798
#   Average accuracy: 0.48589
#   Average turnovers (range [0, 2]):
#     top: 0.27355
#     bottom: 0.41264
#     total: 0.34310
#   Total turnovers:
#     top: 1658.00000
#     bottom: 2501.00000
#     total: 4159.00000
#   Actual profit, if transaction cost were 0.1%: 20.03103
# d = 2.5
#   Avg (year): 1.17494
#   Stddev (year): 0.76293
#   Sharpe ratio (year): 1.54005
#   Profit:
#     positive only: 80.97579
#     negative only: -52.71658
#     total: 28.25921
#     positive to negative ratio: 1.53606
#   Average accuracy: 0.50355
#   Average turnovers (range [0, 2]):
#     top: 0.30622
#     bottom: 0.45686
#     total: 0.38154
#   Total turnovers:
#     top: 1856.00000
#     bottom: 2769.00000
#     total: 4625.00000
#   Actual profit, if transaction cost were 0.1%: 23.63421
# d = 3.0
#   Avg (year): 1.16944
#   Stddev (year): 0.75109
#   Sharpe ratio (year): 1.55699
#   Profit:
#     positive only: 79.10603
#     negative only: -50.97441
#     total: 28.13162
#     positive to negative ratio: 1.55188
#   Average accuracy: 0.50841
#   Average turnovers (range [0, 2]):
#     top: 0.35908
#     bottom: 0.49026
#     total: 0.42467
#   Total turnovers:
#     top: 2176.00000
#     bottom: 2971.00000
#     total: 5147.00000
#   Actual profit, if transaction cost were 0.1%: 22.98462
# d = 3.6
#   Avg (year): 1.10790
#   Stddev (year): 0.74572
#   Sharpe ratio (year): 1.48568
#   Profit:
#     positive only: 75.99691
#     negative only: -48.56768
#     total: 27.42923
#     positive to negative ratio: 1.56476
#   Average accuracy: 0.51338
#   Average turnovers (range [0, 2]):
#     top: 0.46613
#     bottom: 0.57505
#     total: 0.52059
#   Total turnovers:
#     top: 2773.00000
#     bottom: 3421.00000
#     total: 6194.00000
#   Actual profit, if transaction cost were 0.1%: 21.23523
# d = 3.75
#   Avg (year): 1.17217
#   Stddev (year): 0.73858
#   Sharpe ratio (year): 1.58705
#   Profit:
#     positive only: 74.78922
#     negative only: -45.75011
#     total: 29.03911
#     positive to negative ratio: 1.63473
#   Average accuracy: 0.51578
#   Average turnovers (range [0, 2]):
#     top: 0.49991
#     bottom: 0.62563
#     total: 0.56277
#   Total turnovers:
#     top: 2887.00000
#     bottom: 3613.00000
#     total: 6500.00000
#   Actual profit, if transaction cost were 0.1%: 22.53911
# d = 3.9
#   Avg (year): 1.13836
#   Stddev (year): 0.72064
#   Sharpe ratio (year): 1.57964
#   Profit:
#     positive only: 71.78452
#     negative only: -43.51985
#     total: 28.26467
#     positive to negative ratio: 1.64947
#   Average accuracy: 0.51830
#   Average turnovers (range [0, 2]):
#     top: 0.54277
#     bottom: 0.68267
#     total: 0.61272
#   Total turnovers:
#     top: 2995.00000
#     bottom: 3767.00000
#     total: 6762.00000
#   Actual profit, if transaction cost were 0.1%: 21.50267

# %% [markdown]
# ## Dnevni (otežani _means_ i _variance_)

# %%
for T in [60, 120, 200, 500]:
    p = 0.008
    d = 3.75

    method = 'thresh-devs'

    sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_log_diffs, T, weight=0.9 ** (1 / 2000))
    ts, profits, pairs, weights = statistical_arbitrage(sp500_log_diffs, sp500_log_diff_means, sp500_log_diff_vars, p=p, d=d,
                                                        method=method, return_pairs=True, return_weights=True)

    ppairs = partition_as(ts, pairs, weights)
    profit = []
    shares = []
    ts_plot = []
    exp_tops = []
    exp_bottoms = []
    e = 0.0
    for t, ppair, weight in log_progress(list(ppairs)):
        preferences = calculate_preference_flow(ppair, weights=weight)
        m = max(np.abs(list(preferences.values())))
        tops = np.array([k for k, v in preferences.items() if v >= m - e])
        bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
        p = []
        if len(tops) != 0:
            ttops = np.array([t] * len(tops))
            p.extend(trade_singles(sp500_log, ttops, tops, inv=False))
            shares.extend(tops)
            ts_plot.extend(ttops)
        if len(bottoms) != 0:
            tbottoms = np.array([t] * len(bottoms))
            p.extend(trade_singles(sp500_log, tbottoms, bottoms, inv=True))
            shares.extend(bottoms)
            ts_plot.extend(tbottoms)
        exp_tops += [set(tops)]
        exp_bottoms += [set(bottoms)]
        profit.extend([p_ / len(p) for p_ in p])

    shares = np.array(shares)
    ts_plot = np.array(ts_plot)
    profit = np.array(profit)
    
    turnover_top = turnover_ratio(exp_tops)
    turnover_bottom = turnover_ratio(exp_bottoms)

    ts1, profit1 = join_ts_profit(ts_plot, profit)

    plt.figure()
    plt.title('T = {}'.format(T))
    plt.plot(ts1, np.cumsum(profit1))
    plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
    plt.legend(['profit', 'transaction cost included'], loc='best')
    plt.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

    avg = np.mean(profit) * 252
    std = np.std(profit) * np.sqrt(252)
    sharpe = avg / std

    total_positive = np.sum(profit[np.greater(profit, 0.0)])
    total_negative = np.sum(profit[np.less_equal(profit, 0.0)])
    
    print('T = {}'.format(T))
    print('  Avg (year): {:.5f}'.format(avg))
    print('  Stddev (year): {:.5f}'.format(std))
    print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
    print('  Profit:')
    print('    positive only: {:.5f}'.format(total_positive))
    print('    negative only: {:.5f}'.format(total_negative))
    print('    total: {:.5f}'.format(total_positive + total_negative))
    print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
    print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
    print('  Average turnovers (range [0, 2]):')
    print('    top: {:.5f}'.format(np.mean(turnover_top)))
    print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
    print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
    print('  Total turnovers:')
    print('    top: {:.5f}'.format(np.sum(turnover_top)))
    print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
    print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
    print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
        np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# T = 60
#   Avg (year): 0.65916
#   Stddev (year): 0.46672
#   Sharpe ratio (year): 1.41232
#   Profit:
#     positive only: 65.48873
#     negative only: -49.02011
#     total: 16.46862
#     positive to negative ratio: 1.33596
#   Average accuracy: 0.51271
#   Average turnovers (range [0, 2]):
#     top: 0.83401
#     bottom: 0.88285
#     total: 0.85843
#   Total turnovers:
#     top: 4713.00000
#     bottom: 4989.00000
#     total: 9702.00000
#   Actual profit, if transaction cost were 0.1%: 6.76662
# T = 120
#   Avg (year): 0.80069
#   Stddev (year): 0.45678
#   Sharpe ratio (year): 1.75291
#   Profit:
#     positive only: 65.73089
#     negative only: -45.56118
#     total: 20.16972
#     positive to negative ratio: 1.44270
#   Average accuracy: 0.51355
#   Average turnovers (range [0, 2]):
#     top: 0.65418
#     bottom: 0.73791
#     total: 0.69605
#   Total turnovers:
#     top: 3789.00000
#     bottom: 4274.00000
#     total: 8063.00000
#   Actual profit, if transaction cost were 0.1%: 12.10672
# T = 200
#   Avg (year): 0.68673
#   Stddev (year): 0.43235
#   Sharpe ratio (year): 1.58834
#   Profit:
#     positive only: 60.19067
#     negative only: -43.01978
#     total: 17.17089
#     positive to negative ratio: 1.39914
#   Average accuracy: 0.51166
#   Average turnovers (range [0, 2]):
#     top: 0.55856
#     bottom: 0.64390
#     total: 0.60123
#   Total turnovers:
#     top: 3181.00000
#     bottom: 3667.00000
#     total: 6848.00000
#   Actual profit, if transaction cost were 0.1%: 10.32289
# T = 500
#   Avg (year): 0.59814
#   Stddev (year): 0.49657
#   Sharpe ratio (year): 1.20454
#   Profit:
#     positive only: 48.10900
#     negative only: -33.63260
#     total: 14.47639
#     positive to negative ratio: 1.43043
#   Average accuracy: 0.49549
#   Average turnovers (range [0, 2]):
#     top: 0.50815
#     bottom: 0.58422
#     total: 0.54619
#   Total turnovers:
#     top: 2525.00000
#     bottom: 2903.00000
#     total: 5428.00000
#   Actual profit, if transaction cost were 0.1%: 9.04839

# %% [markdown]
# ## Dnevni

# %%
for T in [60, 120, 200, 500]:
    p = None
    d = 3.75

    method = 'thresh-devs'

    sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_log_diffs, T)
    ts, profits, pairs, weights = statistical_arbitrage(sp500_log_diffs, sp500_log_diff_means, sp500_log_diff_vars, p=p, d=d,
                                                        method=method, return_pairs=True, return_weights=True)

    ppairs = partition_as(ts, pairs, weights)
    profit = []
    shares = []
    ts_plot = []
    exp_tops = []
    exp_bottoms = []
    e = 0.0
    for t, ppair, weight in log_progress(list(ppairs)):
        preferences = calculate_preference_flow(ppair, weights=weight)
        m = max(np.abs(list(preferences.values())))
        tops = np.array([k for k, v in preferences.items() if v >= m - e])
        bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
        p = []
        if len(tops) != 0:
            ttops = np.array([t] * len(tops))
            p.extend(trade_singles(sp500_log, ttops, tops, inv=False))
            shares.extend(tops)
            ts_plot.extend(ttops)
        if len(bottoms) != 0:
            tbottoms = np.array([t] * len(bottoms))
            p.extend(trade_singles(sp500_log, tbottoms, bottoms, inv=True))
            shares.extend(bottoms)
            ts_plot.extend(tbottoms)
        exp_tops += [set(tops)]
        exp_bottoms += [set(bottoms)]
        profit.extend([p_ / len(p) for p_ in p])

    shares = np.array(shares)
    ts_plot = np.array(ts_plot)
    profit = np.array(profit)
    
    turnover_top = turnover_ratio(exp_tops)
    turnover_bottom = turnover_ratio(exp_bottoms)

    ts1, profit1 = join_ts_profit(ts_plot, profit)

    plt.figure()
    plt.title('T = {}'.format(T))
    plt.plot(ts1, np.cumsum(profit1))
    plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
    plt.legend(['profit', 'transaction cost included'], loc='best')
    plt.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

    avg = np.mean(profit) * 252
    std = np.std(profit) * np.sqrt(252)
    sharpe = avg / std

    total_positive = np.sum(profit[np.greater(profit, 0.0)])
    total_negative = np.sum(profit[np.less_equal(profit, 0.0)])
    
    print('T = {}'.format(T))
    print('  Avg (year): {:.5f}'.format(avg))
    print('  Stddev (year): {:.5f}'.format(std))
    print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
    print('  Profit:')
    print('    positive only: {:.5f}'.format(total_positive))
    print('    negative only: {:.5f}'.format(total_negative))
    print('    total: {:.5f}'.format(total_positive + total_negative))
    print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
    print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
    print('  Average turnovers (range [0, 2]):')
    print('    top: {:.5f}'.format(np.mean(turnover_top)))
    print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
    print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
    print('  Total turnovers:')
    print('    top: {:.5f}'.format(np.sum(turnover_top)))
    print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
    print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
    print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
        np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 60
#   Avg (year): 1.04361
#   Stddev (year): 0.72661
#   Sharpe ratio (year): 1.43627
#   Profit:
#     positive only: 75.42159
#     negative only: -49.36454
#     total: 26.05705
#     positive to negative ratio: 1.52785
#   Average accuracy: 0.51558
#   Average turnovers (range [0, 2]):
#     top: 0.82109
#     bottom: 0.87619
#     total: 0.84864
#   Total turnovers:
#     top: 4649.00000
#     bottom: 4961.00000
#     total: 9610.00000
#   Actual profit, if transaction cost were 0.1%: 16.44705
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 120
#   Avg (year): 1.10907
#   Stddev (year): 0.71954
#   Sharpe ratio (year): 1.54136
#   Profit:
#     positive only: 75.90178
#     negative only: -48.08713
#     total: 27.81465
#     positive to negative ratio: 1.57842
#   Average accuracy: 0.51424
#   Average turnovers (range [0, 2]):
#     top: 0.63027
#     bottom: 0.71574
#     total: 0.67300
#   Total turnovers:
#     top: 3665.00000
#     bottom: 4162.00000
#     total: 7827.00000
#   Actual profit, if transaction cost were 0.1%: 19.98765
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 200
#   Avg (year): 1.17217
#   Stddev (year): 0.73858
#   Sharpe ratio (year): 1.58705
#   Profit:
#     positive only: 74.78922
#     negative only: -45.75011
#     total: 29.03911
#     positive to negative ratio: 1.63473
#   Average accuracy: 0.51578
#   Average turnovers (range [0, 2]):
#     top: 0.49991
#     bottom: 0.62563
#     total: 0.56277
#   Total turnovers:
#     top: 2887.00000
#     bottom: 3613.00000
#     total: 6500.00000
#   Actual profit, if transaction cost were 0.1%: 22.53911
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 500
#   Avg (year): 0.84341
#   Stddev (year): 0.72676
#   Sharpe ratio (year): 1.16051
#   Profit:
#     positive only: 65.38665
#     negative only: -45.44258
#     total: 19.94407
#     positive to negative ratio: 1.43889
#   Average accuracy: 0.48297
#   Average turnovers (range [0, 2]):
#     top: 0.33364
#     bottom: 0.47415
#     total: 0.40390
#   Total turnovers:
#     top: 1833.00000
#     bottom: 2605.00000
#     total: 4438.00000
#   Actual profit, if transaction cost were 0.1%: 15.50607

# %% [markdown]
# ## Tjedni

# %%
for T in [30, 50, 100]:
    p = None
    d = 3.0

    method = 'thresh-devs'

    sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_5_log_diffs, T)
    ts, profits, pairs, weights = statistical_arbitrage(sp500_5_log_diffs, sp500_log_diff_means, sp500_log_diff_vars, p=p, d=d,
                                                        method=method, return_pairs=True, return_weights=True)

    ppairs = partition_as(ts, pairs, weights)
    profit = []
    shares = []
    ts_plot = []
    exp_tops = []
    exp_bottoms = []
    e = 0.0
    for t, ppair, weight in log_progress(list(ppairs)):
        preferences = calculate_preference_flow(ppair, weights=weight)
        m = max(np.abs(list(preferences.values())))
        tops = np.array([k for k, v in preferences.items() if v >= m - e])
        bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
        p = []
        if len(tops) != 0:
            ttops = np.array([t] * len(tops))
            p.extend(trade_singles(sp500_5_log, ttops, tops, inv=False))
            shares.extend(tops)
            ts_plot.extend(ttops)
        if len(bottoms) != 0:
            tbottoms = np.array([t] * len(bottoms))
            p.extend(trade_singles(sp500_5_log, tbottoms, bottoms, inv=True))
            shares.extend(bottoms)
            ts_plot.extend(tbottoms)
        exp_tops += [set(tops)]
        exp_bottoms += [set(bottoms)]
        profit.extend([p_ / len(p) for p_ in p])

    shares = np.array(shares)
    ts_plot = np.array(ts_plot)
    profit = np.array(profit)
    
    turnover_top = turnover_ratio(exp_tops)
    turnover_bottom = turnover_ratio(exp_bottoms)

    ts1, profit1 = join_ts_profit(ts_plot, profit)

    plt.figure()
    plt.title('T = {}'.format(T))
    plt.plot(ts1, np.cumsum(profit1))
    plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
    plt.legend(['profit', 'transaction cost included'], loc='best')
    plt.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

    avg = np.mean(profit) * 252
    std = np.std(profit) * np.sqrt(252)
    sharpe = avg / std

    total_positive = np.sum(profit[np.greater(profit, 0.0)])
    total_negative = np.sum(profit[np.less_equal(profit, 0.0)])
    
    print('T = {}'.format(T))
    print('  Avg (year): {:.5f}'.format(avg))
    print('  Stddev (year): {:.5f}'.format(std))
    print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
    print('  Profit:')
    print('    positive only: {:.5f}'.format(total_positive))
    print('    negative only: {:.5f}'.format(total_negative))
    print('    total: {:.5f}'.format(total_positive + total_negative))
    print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
    print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
    print('  Average turnovers (range [0, 2]):')
    print('    top: {:.5f}'.format(np.mean(turnover_top)))
    print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
    print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
    print('  Total turnovers:')
    print('    top: {:.5f}'.format(np.sum(turnover_top)))
    print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
    print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
    print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
        np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 30
#   Avg (year): 2.44901
#   Stddev (year): 1.24783
#   Sharpe ratio (year): 1.96261
#   Profit:
#     positive only: 32.19584
#     negative only: -20.28121
#     total: 11.91463
#     positive to negative ratio: 1.58747
#   Average accuracy: 0.55139
#   Average turnovers (range [0, 2]):
#     top: 0.73568
#     bottom: 0.94926
#     total: 0.84247
#   Total turnovers:
#     top: 899.00000
#     bottom: 1160.00000
#     total: 2059.00000
#   Actual profit, if transaction cost were 0.1%: 9.85563
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 50
#   Avg (year): 3.09616
#   Stddev (year): 1.30913
#   Sharpe ratio (year): 2.36505
#   Profit:
#     positive only: 35.10950
#     negative only: -20.31675
#     total: 14.79275
#     positive to negative ratio: 1.72811
#   Average accuracy: 0.58306
#   Average turnovers (range [0, 2]):
#     top: 0.58735
#     bottom: 0.88270
#     total: 0.73502
#   Total turnovers:
#     top: 706.00000
#     bottom: 1061.00000
#     total: 1767.00000
#   Actual profit, if transaction cost were 0.1%: 13.02575
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 100
#   Avg (year): 2.49323
#   Stddev (year): 1.44058
#   Sharpe ratio (year): 1.73071
#   Profit:
#     positive only: 33.79536
#     negative only: -22.36807
#     total: 11.42729
#     positive to negative ratio: 1.51088
#   Average accuracy: 0.54545
#   Average turnovers (range [0, 2]):
#     top: 0.41370
#     bottom: 0.69731
#     total: 0.55551
#   Total turnovers:
#     top: 477.00000
#     bottom: 804.00000
#     total: 1281.00000
#   Actual profit, if transaction cost were 0.1%: 10.14629

# %% [markdown]
# ## Mjesečni

# %%
for T in [30, 40, 50]:
    p = None
    d = 2.0
    

    method = 'thresh-devs'

    sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_22_log_diffs, T)
    ts, profits, pairs, weights = statistical_arbitrage(sp500_22_log_diffs, sp500_log_diff_means, sp500_log_diff_vars, p=p, d=d,
                                                        method=method, return_pairs=True, return_weights=True)

    ppairs = partition_as(ts, pairs, weights)
    profit = []
    shares = []
    ts_plot = []
    exp_tops = []
    exp_bottoms = []
    e = 0.0
    for t, ppair, weight in log_progress(list(ppairs)):
        preferences = calculate_preference_flow(ppair, weights=weight)
        m = max(np.abs(list(preferences.values())))
        tops = np.array([k for k, v in preferences.items() if v >= m - e])
        bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
        p = []
        if len(tops) != 0:
            ttops = np.array([t] * len(tops))
            p.extend(trade_singles(sp500_22_log, ttops, tops, inv=False))
            shares.extend(tops)
            ts_plot.extend(ttops)
        if len(bottoms) != 0:
            tbottoms = np.array([t] * len(bottoms))
            p.extend(trade_singles(sp500_22_log, tbottoms, bottoms, inv=True))
            shares.extend(bottoms)
            ts_plot.extend(tbottoms)
        exp_tops += [set(tops)]
        exp_bottoms += [set(bottoms)]
        profit.extend([p_ / len(p) for p_ in p])

    shares = np.array(shares)
    ts_plot = np.array(ts_plot)
    profit = np.array(profit)
    
    turnover_top = turnover_ratio(exp_tops)
    turnover_bottom = turnover_ratio(exp_bottoms)

    ts1, profit1 = join_ts_profit(ts_plot, profit)

    plt.figure()
    plt.title('T = {}'.format(T))
    plt.plot(ts1, np.cumsum(profit1))
    plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
    plt.legend(['profit', 'transaction cost included'], loc='best')
    plt.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

    avg = np.mean(profit) * 252
    std = np.std(profit) * np.sqrt(252)
    sharpe = avg / std

    total_positive = np.sum(profit[np.greater(profit, 0.0)])
    total_negative = np.sum(profit[np.less_equal(profit, 0.0)])
    
    print('T = {}'.format(T))
    print('  Avg (year): {:.5f}'.format(avg))
    print('  Stddev (year): {:.5f}'.format(std))
    print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
    print('  Profit:')
    print('    positive only: {:.5f}'.format(total_positive))
    print('    negative only: {:.5f}'.format(total_negative))
    print('    total: {:.5f}'.format(total_positive + total_negative))
    print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
    print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
    print('  Average turnovers (range [0, 2]):')
    print('    top: {:.5f}'.format(np.mean(turnover_top)))
    print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
    print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
    print('  Total turnovers:')
    print('    top: {:.5f}'.format(np.sum(turnover_top)))
    print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
    print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
    print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
        np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 30
#   Avg (year): 6.67134
#   Stddev (year): 3.53350
#   Sharpe ratio (year): 1.88802
#   Profit:
#     positive only: 20.40132
#     negative only: -13.65056
#     total: 6.75076
#     positive to negative ratio: 1.49454
#   Average accuracy: 0.56078
#   Average turnovers (range [0, 2]):
#     top: 0.55686
#     bottom: 0.82745
#     total: 0.69216
#   Total turnovers:
#     top: 142.00000
#     bottom: 211.00000
#     total: 353.00000
#   Actual profit, if transaction cost were 0.1%: 6.39776
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 40
#   Avg (year): 4.91365
#   Stddev (year): 3.62257
#   Sharpe ratio (year): 1.35640
#   Profit:
#     positive only: 18.99272
#     negative only: -14.21557
#     total: 4.77716
#     positive to negative ratio: 1.33605
#   Average accuracy: 0.53469
#   Average turnovers (range [0, 2]):
#     top: 0.53061
#     bottom: 0.73878
#     total: 0.63469
#   Total turnovers:
#     top: 130.00000
#     bottom: 181.00000
#     total: 311.00000
#   Actual profit, if transaction cost were 0.1%: 4.46616
# Widget Javascript not detected.  It may not be installed or enabled properly.
# T = 50
#   Avg (year): 2.69668
#   Stddev (year): 3.92770
#   Sharpe ratio (year): 0.68658
#   Profit:
#     positive only: 18.23567
#     negative only: -15.72091
#     total: 2.51476
#     positive to negative ratio: 1.15996
#   Average accuracy: 0.47660
#   Average turnovers (range [0, 2]):
#     top: 0.43404
#     bottom: 0.60000
#     total: 0.51702
#   Total turnovers:
#     top: 102.00000
#     bottom: 141.00000
#     total: 243.00000
#   Actual profit, if transaction cost were 0.1%: 2.27176

# %% [markdown]
# ## Sličnosti omjera cijena

# %%
# razlike povrata po parovima
sp500_ratio_diffs = np.exp(sp500_log_diffs)

T = 120
p = None
d = 3.75

method = 'thresh-devs'

sp500_ratio_diff_means, sp500_ratio_diff_vars = rolling_mean_variance(sp500_ratio_diffs, T)
ts, profits, pairs, weights = statistical_arbitrage(sp500_ratio_diffs, sp500_ratio_diff_means, sp500_ratio_diff_vars, p=p, d=d,
                                                    method=method, return_pairs=True, return_weights=True)

ppairs = partition_as(ts, pairs, weights)
profit = []
shares = []
ts_plot = []
exp_tops = []
exp_bottoms = []
e = 0.0
for t, ppair, weight in log_progress(list(ppairs)):
    preferences = calculate_preference_flow(ppair, weights=weight)
    m = max(np.abs(list(preferences.values())))
    tops = np.array([k for k, v in preferences.items() if v >= m - e])
    bottoms = np.array([k for k, v in preferences.items() if -m + e >= v])
    p = []
    if len(tops) != 0:
        ttops = np.array([t] * len(tops))
        p.extend(trade_singles(sp500_log, ttops, tops, inv=False))
        shares.extend(tops)
        ts_plot.extend(ttops)
    if len(bottoms) != 0:
        tbottoms = np.array([t] * len(bottoms))
        p.extend(trade_singles(sp500_log, tbottoms, bottoms, inv=True))
        shares.extend(bottoms)
        ts_plot.extend(tbottoms)
    exp_tops += [set(tops)]
    exp_bottoms += [set(bottoms)]
    profit.extend([p_ / len(p) for p_ in p])

shares = np.array(shares)
ts_plot = np.array(ts_plot)
profit = np.array(profit)

turnover_top = turnover_ratio(exp_tops)
turnover_bottom = turnover_ratio(exp_bottoms)

ts1, profit1 = join_ts_profit(ts_plot, profit)

plt.figure()
plt.title('T = {}'.format(T))
plt.plot(ts1, np.cumsum(profit1))
plt.plot(ts1, np.cumsum(profit1 - np.sum(np.vstack([turnover_top, turnover_bottom]), axis=0) * 1e-3))
plt.legend(['profit', 'transaction cost included'], loc='best')
plt.autoscale(enable=True, axis='x', tight=True)
plt.grid()

avg = np.mean(profit) * 252
std = np.std(profit) * np.sqrt(252)
sharpe = avg / std

total_positive = np.sum(profit[np.greater(profit, 0.0)])
total_negative = np.sum(profit[np.less_equal(profit, 0.0)])

print('T = {}'.format(T))
print('  Avg (year): {:.5f}'.format(avg))
print('  Stddev (year): {:.5f}'.format(std))
print('  Sharpe ratio (year): {:.5f}'.format(sharpe))
print('  Profit:')
print('    positive only: {:.5f}'.format(total_positive))
print('    negative only: {:.5f}'.format(total_negative))
print('    total: {:.5f}'.format(total_positive + total_negative))
print('    positive to negative ratio: {:.5f}'.format(-total_positive / total_negative))
print('  Average accuracy: {:.5f}'.format(np.count_nonzero(np.greater(profit, 0.0)) / len(profit)))
print('  Average turnovers (range [0, 2]):')
print('    top: {:.5f}'.format(np.mean(turnover_top)))
print('    bottom: {:.5f}'.format(np.mean(turnover_bottom)))
print('    total: {:.5f}'.format(np.mean(np.hstack([turnover_bottom, turnover_top]))))
print('  Total turnovers:')
print('    top: {:.5f}'.format(np.sum(turnover_top)))
print('    bottom: {:.5f}'.format(np.sum(turnover_bottom)))
print('    total: {:.5f}'.format(np.sum(np.hstack([turnover_bottom, turnover_top]))))
print('  Actual profit, if transaction cost were 0.1%: {:.5f}'.format(
    np.sum(profit) - np.sum(np.hstack([turnover_bottom, turnover_top])) * 1e-3))
# Out:
# T = 120
#   Avg (year): 1.10013
#   Stddev (year): 0.73760
#   Sharpe ratio (year): 1.49150
#   Profit:
#     positive only: 79.53109
#     negative only: -51.97536
#     total: 27.55572
#     positive to negative ratio: 1.53017
#   Average accuracy: 0.51030
#   Average turnovers (range [0, 2]):
#     top: 0.59886
#     bottom: 0.65880
#     total: 0.62883
#   Total turnovers:
#     top: 3577.00000
#     bottom: 3935.00000
#     total: 7512.00000
#   Actual profit, if transaction cost were 0.1%: 20.04372

# %%
T = 120
sp500_log_diff_means, sp500_log_diff_vars = rolling_mean_variance(sp500_log_diffs, T)
sp500_ret = sp500_log[1:] - sp500_log[:-1]
sp500_ret_diffs = calculate_pairwise_diffs(sp500_ret)
sp500_ret_diff_means, sp500_ret_diff_vars = rolling_mean_variance(sp500_ret_diffs, T)

plt.figure()
plt.hist(sp500_log_diff_vars.reshape([-1]), bins=100)
print(np.mean(sp500_log_diff_vars))
print(np.median(sp500_log_diff_vars))

plt.figure()
plt.hist(sp500_ret_diff_vars.reshape([-1]), bins=100)
print(np.mean(sp500_ret_diff_vars))
print(np.median(sp500_ret_diff_vars))
# Out:
# 0.0109962557175
# 0.00589431806812
# 0.000685865129232
# 0.000486300972955
